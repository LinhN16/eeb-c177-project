# %% [markdown]
# ## Part 1:

# %%
import numpy

numpy.loadtxt(fname='pima-indians-diabetes.csv',delimiter=',')

#768 rows and 9 columns where the last shows 1 = diabetes and 0 = no diabetes
#column 1: Number of times pregnant
#column 2: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#column 3: diastolic blood pressure (mmHG)
#column 4: triceps skin fold thickness
#column 5: 2-hour serum insulin (mu U/ml)
#column 6: body mass index (weight in kg/(heightin m)^2)
#column 7: diabetes pedigree function
#column 8: age (years)
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
Data = numpy.loadtxt(fname='pima-indians-diabetes.csv',delimiter=',')
import numpy as np

# %%
maxval, minval = np.max(Data, axis=0), np.min(Data,axis=0)
stdval = np.std(Data,axis=0)

#shows the max, min and stdval of all columns given by axis = 0
print ('max:', maxval, ', min:',minval, ', stdev:', stdval)
# Out:
# max: [ 17.   199.   122.    99.   846.    67.1    2.42  81.     1.  ] , min: [ 0.     0.     0.     0.     0.     0.     0.078 21.     0.   ] , stdev: [  3.36738361  31.95179591  19.34320163  15.94182863 115.16894926
#    7.87902573   0.33111282  11.75257265   0.47664076]

# %%
#gives mean # of times pregnant from all patients in the data collection
NumberofTimesPregnant = np.mean(Data[:,0], axis=0)
print (NumberofTimesPregnant)

Data.shape
# Out:
# 3.8450520833333335
# (768, 9)

# %%
#visualize data through a dynamic function that allows user to retrieve data they choose to compare
import matplotlib.pyplot as plt
import os
import sys
def dynamic_plot(): 
    xx= input ("Which column do you want to plot: ")
    x = Data[:,int(xx)]
    plt.hist(x, bins = 50)
    yy= input ("What's the x axis label: ")
    plt.xlabel(str(yy))
    zz= input ("What's the y axis label: ")
    plt.ylabel(str(zz))
    aa= input ("What's the graph title: ")
    plt.title (str(aa))
    plt.show()

# %%
x = Data[:,2]
plt.hist(x, bins = 50)
plt.xlabel('Blood pressure')
plt.ylabel('number of individuals')
plt.title ('Blood Pressure')
plt.show()

# %% [markdown]
# ## Part 2:

# %%
import os
#Read file and datapath
datapath= '/home/eebc177student/developer/repos/eeb-c177-project/analyses'
workingdir= '/home/eebc177student/developer/repos/eeb-c177-project'
os.chdir(datapath)

# %%
#Patient data collected with each row indicating each patient
with open ("pima-indians-diabetes.csv", "r") as ff: 
    for line in ff:
        print (line)
# Out:
# 6,148,72,35,0,33.6,0.627,50,1
#
# 1,85,66,29,0,26.6,0.351,31,0
#
# 8,183,64,0,0,23.3,0.672,32,1
#
# 1,89,66,23,94,28.1,0.167,21,0
#
# 0,137,40,35,168,43.1,2.288,33,1
#
# 5,116,74,0,0,25.6,0.201,30,0
#
# 3,78,50,32,88,31.0,0.248,26,1
#
# 10,115,0,0,0,35.3,0.134,29,0
#
# 2,197,70,45,543,30.5,0.158,53,1
#
# 8,125,96,0,0,0.0,0.232,54,1
#
# 4,110,92,0,0,37.6,0.191,30,0
#
# 10,168,74,0,0,38.0,0.537,34,1
#
# 10,139,80,0,0,27.1,1.441,57,0
#
# 1,189,60,23,846,30.1,0.398,59,1
#
# 5,166,72,19,175,25.8,0.587,51,1
#
# 7,100,0,0,0,30.0,0.484,32,1
#
# 0,118,84,47,230,45.8,0.551,31,1
#
# 7,107,74,0,0,29.6,0.254,31,1
#
# 1,103,30,38,83,43.3,0.183,33,0
#
# 1,115,70,30,96,34.6,0.529,32,1
#
# 3,126,88,41,235,39.3,0.704,27,0
#
# 8,99,84,0,0,35.4,0.388,50,0
#
# 7,196,90,0,0,39.8,0.451,41,1
#
# 9,119,80,35,0,29.0,0.263,29,1
#
# 11,143,94,33,146,36.6,0.254,51,1
#
# 10,125,70,26,115,31.1,0.205,41,1
#
# 7,147,76,0,0,39.4,0.257,43,1
#
# 1,97,66,15,140,23.2,0.487,22,0
#
# 13,145,82,19,110,22.2,0.245,57,0
#
# ...

# %%
#Function allows me to access individual patient's data
dd= []
with open ("pima-indians-diabetes.csv", "r") as ff: 
    for line in ff:
        dd.append(line)

# %%
dd[3]
# Out:
# '1,89,66,23,94,28.1,0.167,21,0\n'

# %%
dd[64]
# Out:
# '7,114,66,0,0,32.8,0.258,42,1\n'

# %%
import csv

with open('pima-indians-diabetes.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
# Out:
# OrderedDict([('6', '1'), ('148', '85'), ('72', '66'), ('35', '29'), ('0', '0'), ('33.6', '26.6'), ('0.627', '0.351'), ('50', '31'), ('1', '0')])
# OrderedDict([('6', '8'), ('148', '183'), ('72', '64'), ('35', '0'), ('0', '0'), ('33.6', '23.3'), ('0.627', '0.672'), ('50', '32'), ('1', '1')])
# OrderedDict([('6', '1'), ('148', '89'), ('72', '66'), ('35', '23'), ('0', '94'), ('33.6', '28.1'), ('0.627', '0.167'), ('50', '21'), ('1', '0')])
# OrderedDict([('6', '0'), ('148', '137'), ('72', '40'), ('35', '35'), ('0', '168'), ('33.6', '43.1'), ('0.627', '2.288'), ('50', '33'), ('1', '1')])
# OrderedDict([('6', '5'), ('148', '116'), ('72', '74'), ('35', '0'), ('0', '0'), ('33.6', '25.6'), ('0.627', '0.201'), ('50', '30'), ('1', '0')])
# OrderedDict([('6', '3'), ('148', '78'), ('72', '50'), ('35', '32'), ('0', '88'), ('33.6', '31.0'), ('0.627', '0.248'), ('50', '26'), ('1', '1')])
# ...

# %%
#this was practice
#inputpath = "pima-indians-diabetes.csv"

# %%
#created an input that allows user to choose the column they want to be made into a new list
#takes each line and gives index value 0-8
#for every value 0-8, it takes each column and outputs it as new list
new_list=[]

def values_list():
    x=input("What column number do you want:")
    for line in open('pima-indians-diabetes.csv'):
        csv_row=line.split()
        temprow=csv_row[0].split(",")
        new_list=temprow([int(x)])
        print(new_list)

# %%
values_list()
# Out:
# What column number do you want:2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-bfbf97cfd16c> in <module>
# ----> 1 values_list()
#
# <ipython-input-27-7919b38a7526> in values_list()
#       9         csv_row=line.split()
#      10         temprow=csv_row[0].split(",")
# ---> 11         new_list=temprow([int(x)])
#      12         print(new_list)
#
# TypeError: 'list' object is not callable

# %%
mycounter = dict()
#creating empty dictionary to count occurences of each value within the chosen column

for value in values_list:
    if author not in mycounter:
        mycounter[author]=0
    mycounter[author] += 1
print (mycounter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c49a5909c16f> in <module>
#       2 #creating empty dictionary to count occurences of each value within the chosen column
#       3
# ----> 4 for value in values_list:
#       5     if author not in mycounter:
#       6         mycounter[author]=0
#
# TypeError: 'function' object is not iterable

# %%
with open('pima-indians-diabetes.csv', mode = 'r', encoding = 'utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    occurances = 0
    for value in columns:
    authorlist= check_auth(value)
    for author in authorlist:
        if author not in mycounter:
            mycounter[author]=0
        mycounter[author] += 1
print (mycounter)
    print('There are {} occurances of values to a key.\n'.format(occurances))
    print('There are  {} rows, with the first row being keys '.format(occurances+1))
    print('and all the subsequent rows being values to the keys.\n')
    
#Useful to look into number of occurences of values within columns

# %%
import pandas as pd
import csv
import re

# %%
inputpath = "pima-indians-diabetes.csv"

# %%
def check_value

# %%
value_counter = dict()
#creating empty dictionary so that we can count the occurences of each value within the columns

for value in data:

# %% [markdown]
# ## Part 3:

# %%
output_file = open('output_f1.txt','w+')

# %%
output_file.write('The average number of pregnancies for individuals is {}.\n'.format(NumberofTimesPregnant))
# Out:
# 73

# %%
output_file.close()
